# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  

results = model.train(data='data.yaml', epochs=50, imgsz=640, batch=16)
# Out:
# Ultralytics YOLOv8.2.32  Python-3.12.4 torch-2.3.1+cpu CPU (Intel Core(TM) i5-9400F 2.90GHz)
# ...

# %%
import torch
print("Pytorch version：")
print(torch.__version__)
print("CUDA Version: ")
print(torch.version.cuda)
print("cuDNN version is :")
print(torch.backends.cudnn.version())
# Out:
# Pytorch version：
# 2.3.1+cpu
# CUDA Version:
# None
# cuDNN version is :
# None

# %%
pip install torch-1.9.0+cpu-cp39-cp39-win_amd64
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: 'torch-1.9.0+cpu-cp39-cp39-win_amd64'

# %%
pip install py-cpuinfo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install thop
# Out:
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchvision
# Out:
# ...
#   Using cached torchvision-0.18.1-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached torch-2.3.1-cp312-cp312-win_amd64.whl.metadata (26 kB)
# ...
#   Using cached pillow-10.3.0-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# ...
#   Using cached filelock-3.15.1-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached sympy-1.12.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached fsspec-2024.6.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# ...
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# ...
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached torchvision-0.18.1-cp312-cp312-win_amd64.whl (1.2 MB)
# Using cached torch-2.3.1-cp312-cp312-win_amd64.whl (159.7 MB)
# ...

# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Using cached opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

model = YOLO('D:/ANPRdeepl/anpr/runs/detect/train3/weights/best.pt')

model.predict('1test_vid.mp4', save=True, imgsz=640, conf=0.1)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1126) D:\ANPRdeepl\anpr\1test_vid.mp4: 384x640 2 licences, 128.7ms
# video 1/1 (frame 2/1126) D:\ANPRdeepl\anpr\1test_vid.mp4: 384x640 2 licences, 119.7ms
# video 1/1 (frame 3/1126) D:\ANPRdeepl\anpr\1test_vid.mp4: 384x640 2 licences, 121.7ms
# video 1/1 (frame 4/1126) D:\ANPRdeepl\anpr\1test_vid.mp4: 384x640 2 licences, 117.7ms
# video 1/1 (frame 5/1126) D:\ANPRdeepl\anpr\1test_vid.mp4: 384x640 2 licences, 118.7ms
# ...

# %%
pip install easyocr
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python predict_modified.py model='D:/ANPRdeepl/anpr/runs/detect/train3/weights/best.pt' source='testvid2.mp4'
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Ultralytics YOLOv8.0.3  Python-3.12.4 torch-2.3.1+cpu CPU
# Fusing layers...
# Model summary: 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# video 1/1 (1/505) D:\ANPRdeepl\anpr\testvid2.mp4: 384x640 1 licence, 131.6ms
# video 1/1 (2/505) D:\ANPRdeepl\anpr\testvid2.mp4: 384x640 1 licence, 118.7ms
# video 1/1 (3/505) D:\ANPRdeepl\anpr\testvid2.mp4: 384x640 1 licence, 129.7ms
# video 1/1 (4/505) D:\ANPRdeepl\anpr\testvid2.mp4: 384x640 1 licence, 129.7ms
# video 1/1 (5/505) D:\ANPRdeepl\anpr\testvid2.mp4: 384x640 1 licence, 130.6ms
# video 1/1 (6/505) D:\ANPRdeepl\anpr\testvid2.mp4: 384x640 1 licence, 116.7ms
# video 1/1 (7/505) D:\ANPRdeepl\anpr\testvid2.mp4: 384x640 1 licence, 116.7ms
# video 1/1 (8/505) D:\ANPRdeepl\anpr\testvid2.mp4: 384x640 1 licence, 127.2ms
# video 1/1 (9/505) D:\ANPRdeepl\anpr\testvid2.mp4: 384x640 1 licence, 130.2ms
# ...
